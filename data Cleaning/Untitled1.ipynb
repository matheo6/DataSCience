# %%
import numpy as np
import pandas as pd
catastro=pd.read_csv('PREDIOS_IDENTIFICADOS_CON_FICHA_CATASTRAL.csv')
print(catastro)
# Out:
#             COMUNA  PREDIOS IDENTIFICADOS CON FICHA CATASTRAL EN ESTRACTO 1  \
# 0       Aeropuerto                                                 55
# 1           Boston                                                333
# 2           Centro                                                 35
# 3          Consota                                               1955
# 4             Cuba                                                346
# 5         Del Cafe                                               2345
# 6        El Jardin                                                 69
# 7           El Oso                                               1407
# 8       El Poblado                                                245
# 9      Ferrocarril                                               2195
# 10          Jardín                                                365
# 11        Olimpica                                                 75
# ...

# %%
li=pd.read_csv('Caracter_sticas_Calidad_del_Agua_-_SIVICAP.csv')
print(li)
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li_nan=li.isnull()

# %%
li_nan
# Out:
#         AÑO  DEPARTAMENTO  MUNICIPO  TOTAL MUESTRAS  RESULTADO COLOR APARENTE  \
# 0     False         False     False           False                     False
# 1     False         False     False           False                     False
# 2     False         False     False           False                     False
# 3     False         False     False           False                     False
# 4     False         False     False           False                     False
# 5     False         False     False           False                     False
# 6     False         False     False           False                     False
# 7     False         False     False           False                     False
# 8     False         False     False           False                     False
# 9     False         False     False           False                     False
# 10    False         False     False           False                     False
# ...

# %%
li
li_sin_nan1=li.dropna(axis=0,how='any')

# %%
li_sin_nan1
# Out:
# Empty DataFrame
# ...

# %%
li_sin_nan2=li.dropna(axis=0,how='all')

# %%
li_sin_nan2
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li_sin_nan3=li.dropna(axis=1,how='any')

# %%
li_sin_nan3
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li_nuevo=li.fillna(value=3)

# %%
li_nuevo
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li_nuevo1=li.fillna(li[li['RESULTADO PH']>=0].mean())

# %%
li_nuevo1
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li_nuevo3=li.fillna(method='bfill',limit=1)

# %%
li_nuevo3
# Out:
#        AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015        Antioquia            Abejorral              44
# 1     2015        Antioquia             Abriaquí              24
# 2     2015        Antioquia           Alejandría              28
# 3     2015        Antioquia                Amagá              26
# 4     2015        Antioquia               Amalfi              58
# 5     2015        Antioquia                Andes              26
# 6     2015        Antioquia          Angelópolis              26
# 7     2015        Antioquia            Angostura              29
# 8     2015        Antioquia                Anorí              25
# 9     2015        Antioquia                 Anza              22
# 10    2015        Antioquia             Apartadó             138
# 11    2015        Antioquia            Arboletes              26
# 12    2015        Antioquia              Argelia             154
# ...

# %%
li['RESULTADO PH']>=7
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
# 5       False
# 6        True
# 7       False
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17      False
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24      False
# 25      False
# 26      False
# 27       True
# 28       True
# 29      False
#         ...
# 989      True
# 990      True
# 991      True
# 992      True
# 993      True
# 994      True
# 995      True
# 996      True
# 997      True
# 998      True
# 999      True
# 1000     True
# 1001     True
# 1002     True
# 1003     True
# 1004     True
# 1005     True
# 1006     True
# 1007     True
# 1008     True
# 1009     True
# 1010     True
# 1011     True
# 1012    False
# 1013    False
# 1014    False
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# ...

# %%
li[li['RESULTADO PH']>=8]
# Out:
#       AÑO        DEPARTAMENTO                MUNICIPO  TOTAL MUESTRAS  \
# 78   2015           Antioquia                   Peque              18
# 112  2015           Antioquia                 Uramita              49
# 156  2015             Bolívar                    Achí              11
# 169  2015             Bolívar    El Carmen De Bolívar               8
# 175  2015             Bolívar               Margarita              11
# 186  2015             Bolívar            San Fernando              12
# 251  2015              Boyacá                 Macanal              25
# 456  2015             Córdoba                   Chinú              36
# 498  2015        Cundinamarca                El Peñón              12
# 550  2015        Cundinamarca                 Quipile              11
# 592  2015        Cundinamarca                 Zipacón              24
# 656  2015           Magdalena                  Guamal              65
# ...

# %%
li['MUNICIPO'][li['RESULTADO PH']>=8]
# Out:
# 78                      Peque
# 112                   Uramita
# 156                      Achí
# 169      El Carmen De Bolívar
# 175                 Margarita
# 186              San Fernando
# 251                   Macanal
# 456                     Chinú
# 498                  El Peñón
# 550                   Quipile
# 592                   Zipacón
# 656                    Guamal
# 669    Santa Bárbara De Pinto
# 697               San Juanito
# 703                    Aldana
# 704                    Ancuyá
# 778                 El Carmen
# 787                Los Patios
# 909            Puerto Wilches
# 936                   Corozal
# 942              Los Palmitos
# 943                  Majagual
# 944                    Morroa
# 945                    Ovejas
# 947                   Sampués
# 948           San Benito Abad
# 949       San Juan De Betulia
# 950         San Luis De Sincé
# 953                 San Pedro
# 955                 Sincelejo
# Name: MUNICIPO, dtype: object

# %%
li[(li['RESULTADO PH']>=8)&(li['RESULTADO COLOR APARENTE']>=3)]
# Out:
#       AÑO        DEPARTAMENTO                MUNICIPO  TOTAL MUESTRAS  \
# 78   2015           Antioquia                   Peque              18
# 112  2015           Antioquia                 Uramita              49
# 156  2015             Bolívar                    Achí              11
# 169  2015             Bolívar    El Carmen De Bolívar               8
# 175  2015             Bolívar               Margarita              11
# 186  2015             Bolívar            San Fernando              12
# 251  2015              Boyacá                 Macanal              25
# 656  2015           Magdalena                  Guamal              65
# 669  2015           Magdalena  Santa Bárbara De Pinto              13
# 697  2015                Meta             San Juanito              18
# 703  2015              Nariño                  Aldana              34
# 704  2015              Nariño                  Ancuyá              76
# ...

# %%
li.where(li['RESULTADO PH']>7)
# Out:
#          AÑO     DEPARTAMENTO             MUNICIPO  TOTAL MUESTRAS  \
# 0     2015.0        Antioquia            Abejorral            44.0
# 1     2015.0        Antioquia             Abriaquí            24.0
# 2        NaN              NaN                  NaN             NaN
# 3     2015.0        Antioquia                Amagá            26.0
# 4     2015.0        Antioquia               Amalfi            58.0
# 5        NaN              NaN                  NaN             NaN
# 6     2015.0        Antioquia          Angelópolis            26.0
# 7        NaN              NaN                  NaN             NaN
# 8     2015.0        Antioquia                Anorí            25.0
# 9     2015.0        Antioquia                 Anza            22.0
# 10    2015.0        Antioquia             Apartadó           138.0
# 11       NaN              NaN                  NaN             NaN
# 12    2015.0        Antioquia              Argelia           154.0
# ...

# %%
li.mask(li['RESULTADO PH']>7)
# Out:
#          AÑO DEPARTAMENTO        MUNICIPO  TOTAL MUESTRAS  \
# 0        NaN          NaN             NaN             NaN
# 1        NaN          NaN             NaN             NaN
# 2     2015.0    Antioquia      Alejandría            28.0
# 3        NaN          NaN             NaN             NaN
# 4        NaN          NaN             NaN             NaN
# 5     2015.0    Antioquia           Andes            26.0
# 6        NaN          NaN             NaN             NaN
# 7     2015.0    Antioquia       Angostura            29.0
# 8        NaN          NaN             NaN             NaN
# 9        NaN          NaN             NaN             NaN
# 10       NaN          NaN             NaN             NaN
# 11    2015.0    Antioquia       Arboletes            26.0
# 12       NaN          NaN             NaN             NaN
# 13       NaN          NaN             NaN             NaN
# 14       NaN          NaN             NaN             NaN
# ...

# %%
li.isin([26.0,28.0])
# Out:
#         AÑO  DEPARTAMENTO  MUNICIPO  TOTAL MUESTRAS  RESULTADO COLOR APARENTE  \
# 0     False         False     False           False                     False
# 1     False         False     False           False                     False
# 2     False         False     False            True                     False
# 3     False         False     False            True                     False
# 4     False         False     False           False                     False
# 5     False         False     False            True                     False
# 6     False         False     False            True                     False
# 7     False         False     False           False                     False
# 8     False         False     False           False                     False
# 9     False         False     False           False                     False
# 10    False         False     False           False                     False
# ...

# %%
li.isin({'TOTAL MUESTRAS':[10.0,19.0,20.0,30.0,44.0]})
# Out:
#         AÑO  DEPARTAMENTO  MUNICIPO  TOTAL MUESTRAS  RESULTADO COLOR APARENTE  \
# 0     False         False     False            True                     False
# 1     False         False     False           False                     False
# 2     False         False     False           False                     False
# 3     False         False     False           False                     False
# 4     False         False     False           False                     False
# 5     False         False     False           False                     False
# 6     False         False     False           False                     False
# 7     False         False     False           False                     False
# 8     False         False     False           False                     False
# 9     False         False     False           False                     False
# 10    False         False     False           False                     False
# ...

# %%
li.query('TOTAL MUESTRAS > AÑO')
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-61-b3a9457ccdd7>", line 1, in <module>
#     li.query('TOTAL MUESTRAS > AÑO')
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 2847, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 2962, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 291, in eval
#     truediv=truediv)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 739, in __init__
#     self.terms = self.parse()
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 756, in parse
# ...

# %%
li['TOTAL MUESTRAS']
# Out:
# 0        44
# 1        24
# 2        28
# 3        26
# 4        58
# 5        26
# 6        26
# 7        29
# 8        25
# 9        22
# 10      138
# 11       26
# 12      154
# 13       25
# 14       41
# 15      127
# 16       29
# 17       26
# 18       27
# 19       27
# 20       25
# 21       21
# 22       24
# 23      128
# 24       28
# 25       28
# 26       27
# 27       26
# 28       43
# 29       29
#        ...
# 989      31
# 990     118
# 991      95
# 992      57
# 993      72
# 994      39
# 995      40
# 996     170
# 997      17
# 998      12
# 999      27
# 1000     63
# 1001     23
# 1002     50
# 1003     23
# 1004     20
# 1005    197
# 1006     23
# 1007     32
# 1008     29
# 1009     26
# 1010    288
# 1011     54
# 1012      9
# 1013     34
# 1014      8
# 1015     49
# 1016     25
# 1017     43
# 1018     54
# Name: TOTAL MUESTRAS, Length: 1019, dtype: int64

# %%
li['AÑO']
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
# 5       2015
# 6       2015
# 7       2015
# 8       2015
# 9       2015
# 10      2015
# 11      2015
# 12      2015
# 13      2015
# 14      2015
# 15      2015
# 16      2015
# 17      2015
# 18      2015
# 19      2015
# 20      2015
# 21      2015
# 22      2015
# 23      2015
# 24      2015
# 25      2015
# 26      2015
# 27      2015
# 28      2015
# 29      2015
#         ...
# 989     2015
# 990     2015
# 991     2015
# 992     2015
# 993     2015
# 994     2015
# 995     2015
# 996     2015
# 997     2015
# 998     2015
# 999     2015
# 1000    2015
# 1001    2015
# 1002    2015
# 1003    2015
# 1004    2015
# 1005    2015
# 1006    2015
# 1007    2015
# 1008    2015
# 1009    2015
# 1010    2015
# 1011    2015
# 1012    2015
# 1013    2015
# 1014    2015
# 1015    2015
# 1016    2015
# 1017    2015
# 1018    2015
# Name: AÑO, Length: 1019, dtype: int64

# %%
li.query('AÑO>TOTAL MUESTRAS')
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-64-19b7aa4fd427>", line 1, in <module>
#     li.query('AÑO>TOTAL MUESTRAS')
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 2847, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py", line 2962, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 291, in eval
#     truediv=truediv)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 739, in __init__
#     self.terms = self.parse()
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 756, in parse
# ...

# %%
li.query('AÑO > AÑO')
# Out:
# Empty DataFrame
# ...
