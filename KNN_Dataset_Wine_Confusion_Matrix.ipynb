# %% [markdown]
# <a href="https://colab.research.google.com/github/matheo6/DataSCience/blob/master/KNN_Dataset_Wine_Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier

# %%
wine=datasets.load_wine()
type(wine)
dir(wine)
wine.DESCR



wine.data
wine.target
x_train,x_test,y_train,y_test= train_test_split(wine.data,wine.target)
x_train
y_train
x_test
y_test


knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
knn.predict(x_test)
y_test

##plot
title_options =[("matris de confusion sin normalizar", None),("matriz de confusion normalizada","true")]
for title, normalize in title_options:
    disp=plot_confusion_matrix(knn,x_test,y_test, cmap=plt.cm.Blues,normalize=normalize)
    disp.ax_.set_title(title)
    print(title)
    print(disp.confusion_matrix)
plt.show()
# Out:
# matris de confusion sin normalizar
# [[13  0  1]
#  [ 2 10  8]
#  [ 1  3  7]]
# matriz de confusion normalizada
# [[0.92857143 0.         0.07142857]
#  [0.1        0.5        0.4       ]
#  [0.09090909 0.27272727 0.63636364]]
